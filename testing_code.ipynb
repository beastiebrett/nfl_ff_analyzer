# %%
import json


# def compile_rosters():
# Load in data from data/1115121531081822208_rosters.json
with open('data/1115121531081822208_rosters.json', 'r') as f:
    raw_roster_data = json.load(f)
# print(raw_roster_data[0]["players"])

# Loop through raw_roster_data and make a dictionary of each teams player roster
roster_player_ids = {}
for i in raw_roster_data:
    # print(i["players"])
    roster_player_ids[i["roster_id"]] = i["players"]

# Loop through each roster_player_ids and get that players actual name and other information from data/all_nfl_players.json
with open('data/all_nfl_players.json', 'r') as f:
    raw_player_data = json.load(f)

for key, value in roster_player_ids.items():
    # print(f"{key}: {value}")
    for i in value:
        print(i)
        print(raw_player_data[str(i)]["first_name"]+" "+raw_player_data[str(i)]["last_name"])
        
# for roster in roster_player_ids:
#     for player in roster_player_ids[roster]:
#         for player_data in raw_player_data:
#             if player_data['id'] == player:
#                 print(player_data['full_name'])


# return user_rosters
# Out:
# 11604
# Brock Bowers
# 11618
# Jalen McMillan
# 11628
# Marvin Harrison
# 11635
# Ladd McConkey
# 11655
# Tyrone Tracy
# 3198
# Derrick Henry
# 4227
# Harrison Butker
# 5119
# Jason Sanders
# 5947
# Jakobi Meyers
# 6770
# Joe Burrow
# 6806
# J.K. Dobbins
# 6963
# Patrick Taylor
# 7526
# Jaylen Waddle
# 8220
# Sincere McCormick
# 9493
# Puka Nacua
# 9753
# Zach Charbonnet
# BAL
# Baltimore Ravens
# MIN
# Minnesota Vikings
# 10937
# Jake Moody
# 11583
# Jonathon Brooks
# 11631
# Brian Thomas
# 11651
# Isaac Guerendo
# 4033
# David Njoku
# 5012
# Mark Andrews
# 5849
# Kyler Murray
# 7090
# Darnell Mooney
# 7525
# DeVonta Smith
# 7569
# Nico Collins
# 8150
# Kyren Williams
# 8210
# Chig Okonkwo
# 8228
# Jaylen Warren
# 9486
# Dontayvion Wicks
# 9508
# Tyjae Spears
# 9509
# Bijan Robinson
# KC
# Kansas City Chiefs
# LV
# Las Vegas Raiders
# 10236
# Dalton Kincaid
# 11563
# Bo Nix
# 11579
# Audric Estime
# 1479
# Keenan Allen
# 2133
# Davante Adams
# 2374
# Tyler Lockett
# 3294
# ...

# %%
print(raw_player_data['11604'])
# Out:
# {'team_abbr': None, 'years_exp': 1, 'number': 89, 'high_school': 'Napa (CA)', 'age': 22, 'search_first_name': 'brock', 'team_changed_at': None, 'search_last_name': 'bowers', 'oddsjam_id': '890CB831F75E', 'hashtag': '#brockbowers-NFL-LV-89', 'sport': 'nfl', 'depth_chart_position': 'TE', 'active': True, 'rotowire_id': 17693, 'injury_body_part': None, 'opta_id': None, 'search_rank': 60, 'swish_id': 1285917, 'fantasy_positions': ['TE'], 'practice_participation': None, 'rotoworld_id': None, 'status': 'Active', 'birth_country': None, 'player_id': '11604', 'gsis_id': None, 'birth_date': '2002-12-13', 'injury_status': None, 'first_name': 'Brock', 'sportradar_id': 'ad9fc7e3-0a6d-4e41-84c2-cf43b71aee13', 'weight': '230', 'full_name': 'Brock Bowers', 'injury_start_date': None, 'fantasy_data_id': None, 'birth_city': None, 'injury_notes': None, 'stats_id': None, 'practice_description': None, 'yahoo_id': None, 'espn_id': None, 'position': 'TE', 'depth_chart_order': 1, 'last_name': 'Bowers', 'team'
# ...

# %%
compile_rosters()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 compile_rosters()
#
# Cell In[1], line 10, in compile_rosters()
#       8 user_rosters = {}
#       9 for i in roster_data:
# ---> 10     user_rosters[i] = roster_data[i]['players']
#      11 return user_rosters
#
# TypeError: list indices must be integers or slices, not dict
